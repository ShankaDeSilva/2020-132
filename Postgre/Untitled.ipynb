# %%
import googlemaps
from datetime import datetime
import gmplot

# %%
apikey='AIzaSyDwYEdiAwbvCUTm8cIotNL0AVVnd6BMRjQ'

# %%
var1 = 81.40232
var2 = 6.27829

# %%
import psycopg2
from psycopg2 import Error
var1 = 81.40232
var2 = 6.27829

try:
    connection = psycopg2.connect(user = 'postgres',
                                 password = 'root',
                                 host = 'localhost',
                                 port = '5432',
                                 database = 'nyc')
    
    cursor = connection.cursor()
    
    create_route = ("""SELECT id, cost, ST_AsText(road) AS geom, road, distance, x1, y1, x2, y2, source, target
FROM pgr_aStar(
   'SELECT id, source, target, st_length(road, true) as cost, distance as reverse_cost, x1, y1, x2, y2 FROM graph',
   (SELECT source FROM graph
    ORDER BY ST_Distance(
        ST_StartPoint(road),
        ST_SetSRID(ST_MakePoint(%s, %s), 4326),
        true
   ) ASC
   LIMIT 1),
   
  (SELECT source FROM graph
    ORDER BY ST_Distance(
        ST_StartPoint(road),
        ST_SetSRID(ST_MakePoint(81.46917, 6.31331), 4326),
        true
   ) ASC
   LIMIT 1)
) as pt
JOIN graph rd ON pt.edge = rd.id;""", (var1, var2))
    
    cursor.execute(create_route)
    
    records = cursor.fetchall()
    
    print("Rows and columns")
    for row in records:
        print("id = ", row[0], ),
        print("cost = ", row[1], ),
        print("road = ", row[2], ),
        print("distance = ", row[4], ),
        print("X1 = ", row[5], ),
        print("Y1 = ", row[6], ),
        print("X2 = ", row[7], ),
        print("Y2 = ", row[8], "\n"),
       
        
except (Exception, psycopg2.Error) as error :
    print("Error while fetching data from PostgreSQL", error)

except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
finally:
    #closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
# Out:
# Error while fetching data from PostgreSQL argument 1 must be a string or unicode object: got tuple instead
# PostgreSQL connection is closed

# %%
gmap = gmplot.GoogleMapPlotter(6.31328,81.46281, 14, apikey=apikey)
gmap.marker(6.31328,81.46281, color='cornflowerblue')

# %%
gmap.draw('map.html')

# %%
import gmplot 
  
latitude_list = [ 81.44299, 81.44488, 81.44703 ] 
longitude_list = [ 6.30756, 6.30747, 6.30842 ] 
  
gmap3 = gmplot.GoogleMapPlotter(6.30747, 
                                81.44488, 13) 
  
# scatter method of map object  
# scatter points on the google map 
gmap3.scatter( latitude_list, longitude_list, '# FF0000', 
                              size = 40, marker = False ) 
  
# Plot method Draw a line in 
# between given coordinates 
gmap3.plot(latitude_list, longitude_list,  
           'cornflowerblue', edge_width = 2.5) 
  
gmap3.draw( "map.html" )

# %%
import psycopg2
from psycopg2 import Error
var1 = 81.40232
var2 = 6.27829

try:
    connection = psycopg2.connect(user = 'postgres',
                                 password = 'root',
                                 host = 'localhost',
                                 port = '5432',
                                 database = 'nyc')
    
    cursor = connection.cursor()
    
    
    
    cursor.execute("""SELECT id, cost, ST_AsText(road) AS geom, road, distance, x1, y1, x2, y2, source, target
FROM pgr_aStar(
   'SELECT id, source, target, st_length(road, true) as cost, distance as reverse_cost, x1, y1, x2, y2 FROM graph',
   (SELECT source FROM graph
    ORDER BY ST_Distance(
        ST_StartPoint(road),
        ST_SetSRID(ST_MakePoint(%s, %s), 4326),
        true
   ) ASC
   LIMIT 1),
   
  (SELECT source FROM graph
    ORDER BY ST_Distance(
        ST_StartPoint(road),
        ST_SetSRID(ST_MakePoint(81.46917, 6.31331), 4326),
        true
   ) ASC
   LIMIT 1)
) as pt
JOIN graph rd ON pt.edge = rd.id;""", (var1, var2))
    
    records = cursor.fetchall()
    
    print("Rows and columns")
    for row in records:
        print("id = ", row[0], ),
        print("cost = ", row[1], ),
        print("road = ", row[2], ),
        print("distance = ", row[4], ),
        print("X1 = ", row[5], ),
        print("Y1 = ", row[6], ),
        print("X2 = ", row[7], ),
        print("Y2 = ", row[8], "\n"),
       
        
except (Exception, psycopg2.Error) as error :
    print("Error while fetching data from PostgreSQL", error)

except (Exception, psycopg2.Error) as error :
    print ("Error while connecting to PostgreSQL", error)
finally:
    #closing database connection.
        if(connection):
            cursor.close()
            connection.close()
            print("PostgreSQL connection is closed")
# Out:
# Rows and columns
# id =  1
# cost =  2067.17425936608
# road =  LINESTRING(81.40232 6.27829,81.40187 6.28079,81.40208 6.28111,81.40615 6.28183,81.40936 6.2811,81.4117 6.28135,81.41346 6.28156,81.41681 6.28411)
# distance =  2072
# X1 =  81.40232
# Y1 =  6.27829
# X2 =  81.41681
# Y2 =  6.28411
#
# id =  5
# cost =  1893.4540044881514
# road =  LINESTRING(81.41681 6.28411,81.42068 6.28601,81.42301 6.2862,81.43069 6.29331)
# distance =  2191
# X1 =  81.41681
# Y1 =  6.28411
# X2 =  81.43069
# Y2 =  6.29331
#
# id =  9
# cost =  396.8641658426379
# road =  LINESTRING(81.43069 6.29331,81.43332 6.29575)
# distance =  400
# X1 =  81.43069
# Y1 =  6.29331
# X2 =  81.43332
# Y2 =  6.29575
#
# id =  33
# cost =  827.799881719406
# road =  LINESTRING(81.43331 6.29578,81.4387745 6.3008924)
# distance =  830
# X1 =  81.43331
# Y1 =  6.29578
# X2 =  81.4387745
# Y2 =  6.3008924
#
# id =  37
# cost =  936.8766471317813
# road =  LINESTRING(81.43877 6.30089,81.44125 6.30322,81.44151 6.30639,81.44299 6.30756)
# distance =  940
# X1 =  81.43877
# Y1 =  6.30089
# X2 =  81.44299
# Y2 =  6.30756
#
# id =  69
# cost =  2511.3944587383985
# road =  LINESTRING(81.44299 6.30756,81.44488 6.30747,81.44703 6.30842,81.45027 6.30695,81.45509 6.30764,81.45794 6.30908,81.45888 6.30901,81.45984 6.30975,81.46181 6.31263,81.46281 6.31328)
# distance =  2521
# X1 =  81.44299
# Y1 =  6.30756
# X2 =  81.46281
# Y2 =  6.31328
#
# id =  71
# cost =  1065.9104861579326
# road =  LINESTRING(81.46281 6.31328,81.46669 6.31239,81.46917 6.31331,81.4703 6.3155,81.47069 6.31588)
# distance =  1082
# X1 =  81.46281
# Y1 =  6.31328
# X2 =  81.47069
# Y2 =  6.31588
#
# PostgreSQL connection is closed
